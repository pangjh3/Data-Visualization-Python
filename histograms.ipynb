# %%
#seaborn reference : http://seaborn.pydata.org/index.html

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('iris')
 
# print(df)
# print(df["sepal_length"])
# print(type(df["sepal_length"]))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# ...

# %%
# plot
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)
sns.distplot( df["sepal_length"] , color="skyblue", ax=axes[0, 0])
sns.distplot( df["sepal_width"] , color="olive", ax=axes[0, 1])
sns.distplot( df["petal_length"] , color="gold", ax=axes[1, 0])
sns.distplot( df["petal_width"] , color="teal", ax=axes[1, 1])

# %%
example = np.array([1,1,2,3,4,4.5,5,6,7,8,9,10,12])
sns.distplot(example, bins= 5)

# %%
sns.distplot(example, hist=False, kde=True, rug=True)

#hist：bool型变量，控制是否绘制直方图，默认为True

#kde：bool型变量，控制是否绘制核密度估计曲线，默认为True

#rug：bool型变量，控制是否绘制对应rugplot的部分，默认为False
